# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data\\Dataset for Data Analytics - Sheet1.csv')
df.sample(10)
# Out:
#         OrderID        Date CustomerID  Product  Quantity  UnitPrice  \
# 126   ORD200126  2025-05-03     C55606     Desk         4     275.50
# 922   ORD200922  2024-06-17     C81857     Desk         2     563.82
# 521   ORD200521  2024-02-25     C82318    Phone         1     528.06
# 1183  ORD201183  2023-04-05     C12607     Desk         1     281.52
# 628   ORD200628  2023-03-26     C18717  Printer         5     558.63
# 437   ORD200437  2024-04-18     C63378    Phone         1     512.39
# 534   ORD200534  2024-06-06     C73289    Chair         3     648.59
# 1040  ORD201040  2023-11-15     C13169   Tablet         1     536.07
# 1128  ORD201128  2023-08-17     C49198  Monitor         3     646.79
# 475   ORD200475  2025-04-19     C29844   Tablet         2     438.62
#
#      ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 126      353 Main St     Gift Card     Shipped    TRK68250319            8
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1200 entries, 0 to 1199
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   OrderID          1200 non-null   object
#  1   Date             1200 non-null   object
#  2   CustomerID       1200 non-null   object
#  3   Product          1200 non-null   object
#  4   Quantity         1200 non-null   int64
#  5   UnitPrice        1200 non-null   float64
#  6   ShippingAddress  1200 non-null   object
#  7   PaymentMethod    1200 non-null   object
#  8   OrderStatus      1200 non-null   object
#  9   TrackingNumber   1200 non-null   object
#  10  ItemsInCart      1200 non-null   int64
#  11  CouponCode       891 non-null    object
#  12  ReferralSource   1200 non-null   object
#  13  TotalPrice       1200 non-null   float64
# dtypes: float64(2), int64(2), object(10)
# memory usage: 131.4+ KB

# %%
df.describe()
# Out:
#           Quantity    UnitPrice  ItemsInCart   TotalPrice
# count  1200.000000  1200.000000  1200.000000  1200.000000
# mean      2.945833   356.412750     5.485000  1053.968300
# std       1.407557   197.177146     2.281983   819.856558
# min       1.000000    11.390000     1.000000    11.390000
# 25%       2.000000   186.062500     4.000000   410.520000
# 50%       3.000000   364.210000     5.000000   823.615000
# 75%       4.000000   521.570000     7.000000  1578.475000
# max       5.000000   699.930000    10.000000  3456.400000

# %%
df.columns
# Out:
# Index(['OrderID', 'Date', 'CustomerID', 'Product', 'Quantity', 'UnitPrice',
#        'ShippingAddress', 'PaymentMethod', 'OrderStatus', 'TrackingNumber',
#        'ItemsInCart', 'CouponCode', 'ReferralSource', 'TotalPrice'],
#       dtype='object')

# %%
df.dtypes
# Out:
# OrderID             object
# Date                object
# CustomerID          object
# Product             object
# Quantity             int64
# UnitPrice          float64
# ShippingAddress     object
# PaymentMethod       object
# OrderStatus         object
# TrackingNumber      object
# ItemsInCart          int64
# CouponCode          object
# ReferralSource      object
# TotalPrice         float64
# dtype: object

# %%
df.head()
# Out:
#      OrderID        Date CustomerID  Product  Quantity  UnitPrice  \
# 0  ORD200000  2023-01-04     C72649  Monitor         5     570.62
# 1  ORD200001  2024-08-23     C75739    Phone         2     151.35
# 2  ORD200002  2024-02-27     C81728   Tablet         5     550.68
# 3  ORD200003  2023-10-15     C33540    Chair         1     273.19
# 4  ORD200004  2025-05-08     C81840  Printer         4     626.01
#
#   ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# 0     928 Main St    Debit Card     Shipped    TRK37947903            7
# 1     823 Main St        Online     Shipped    TRK91186779            3
# 2     512 Main St   Credit Card   Cancelled    TRK42903982            8
# 3     275 Main St    Debit Card    Returned    TRK62788070            5
# 4     668 Main St        Online   Delivered    TRK29241424            8
#
#   CouponCode ReferralSource  TotalPrice
# 0     SAVE10      Instagram     2853.10
# 1     SAVE10       Referral      302.70
# ...

# %%
df.shape
# Out:
# (1200, 14)

# %%
df['Date'] = pd.to_datetime(df['Date'])

df.dtypes
# Out:
# OrderID                    object
# Date               datetime64[ns]
# CustomerID                 object
# Product                    object
# Quantity                    int64
# UnitPrice                 float64
# ShippingAddress            object
# PaymentMethod              object
# OrderStatus                object
# TrackingNumber             object
# ItemsInCart                 int64
# CouponCode                 object
# ReferralSource             object
# TotalPrice                float64
# dtype: object

# %%
product = df['Product']
order_status = df['OrderStatus']
referral_source = df['ReferralSource']
payment_method = df['PaymentMethod']

print((product.value_counts()).sort_values())
print((order_status.value_counts()).sort_values())
print((referral_source.value_counts()).sort_values())
print((payment_method.value_counts()).sort_values())
# Out:
# Product
# Phone      156
# Monitor    163
# Desk       170
# Laptop     173
# Chair      178
# Tablet     179
# Printer    181
# Name: count, dtype: int64
# OrderStatus
# Delivered    231
# Shipped      235
# Pending      237
# Returned     247
# Cancelled    250
# Name: count, dtype: int64
# ReferralSource
# Referral     222
# Facebook     228
# Google       241
# Email        250
# Instagram    259
# Name: count, dtype: int64
# PaymentMethod
# Gift Card      230
# Debit Card     232
# Credit Card    234
# Cash           246
# Online         258
# Name: count, dtype: int64

# %%
pd = [product, order_status, referral_source, payment_method]
for arr in pd :
    print(f"Column: {arr.name}")
    print("Count  :", arr.count())
    print("Unique :", arr.nunique())
    print("Min    :", arr.value_counts().min())
    print("Max    :", arr.value_counts().max())
    print("Mode   :", arr.mode().tolist())

    print("\nValue Counts (Ascending):")
    print(arr.value_counts().sort_values())
# Out:
# Column: Product
# Count  : 1200
# Unique : 7
# Min    : 156
# Max    : 181
# Mode   : ['Printer']
#
# Value Counts (Ascending):
# Product
# Phone      156
# Monitor    163
# Desk       170
# Laptop     173
# Chair      178
# Tablet     179
# Printer    181
# Name: count, dtype: int64
# Column: OrderStatus
# Count  : 1200
# Unique : 5
# Min    : 231
# Max    : 250
# Mode   : ['Cancelled']
#
# Value Counts (Ascending):
# OrderStatus
# Delivered    231
# Shipped      235
# Pending      237
# Returned     247
# Cancelled    250
# Name: count, dtype: int64
# Column: ReferralSource
# Count  : 1200
# Unique : 5
# Min    : 222
# Max    : 259
# Mode   : ['Instagram']
#
# Value Counts (Ascending):
# ReferralSource
# Referral     222
# Facebook     228
# Google       241
# Email        250
# Instagram    259
# Name: count, dtype: int64
# Column: PaymentMethod
# Count  : 1200
# Unique : 5
# Min    : 230
# Max    : 258
# Mode   : ['Online']
#
# Value Counts (Ascending):
# PaymentMethod
# ...

# %%
df.isna().sum()
# Out:
# OrderID              0
# Date                 0
# CustomerID           0
# Product              0
# Quantity             0
# UnitPrice            0
# ShippingAddress      0
# PaymentMethod        0
# OrderStatus          0
# TrackingNumber       0
# ItemsInCart          0
# CouponCode         309
# ReferralSource       0
# TotalPrice           0
# dtype: int64

# %%
df['CouponCode'] = df['CouponCode'].fillna('No coupon')

# %%
df
# Out:
#         OrderID       Date CustomerID  Product  Quantity  UnitPrice  \
# 0     ORD200000 2023-01-04     C72649  Monitor         5     570.62
# 1     ORD200001 2024-08-23     C75739    Phone         2     151.35
# 2     ORD200002 2024-02-27     C81728   Tablet         5     550.68
# 3     ORD200003 2023-10-15     C33540    Chair         1     273.19
# 4     ORD200004 2025-05-08     C81840  Printer         4     626.01
# ...         ...        ...        ...      ...       ...        ...
# 1195  ORD201195 2024-06-20     C21126     Desk         1     107.04
# 1196  ORD201196 2024-03-04     C20095  Monitor         2     662.53
# 1197  ORD201197 2023-07-13     C79674   Tablet         2     436.84
# 1198  ORD201198 2024-08-22     C64753    Chair         4     262.52
# 1199  ORD201199 2023-06-11     C57502   Tablet         4     560.58
#
#      ShippingAddress PaymentMethod OrderStatus TrackingNumber  ItemsInCart  \
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1200, 14)

# %%
print(df['CouponCode'].nunique())
print(df['CouponCode'].unique())
# Out:
# 4
# ['SAVE10' 'FREESHIP' 'No coupon' 'WINTER15']

# %%
coupons = df['CouponCode'].value_counts().sort_values()
coupons
# Out:
# CouponCode
# SAVE10       286
# WINTER15     292
# No coupon    309
# FREESHIP     313
# Name: count, dtype: int64

# %%
df.nunique().sort_values()
# Out:
# CouponCode            4
# PaymentMethod         5
# OrderStatus           5
# Quantity              5
# ReferralSource        5
# Product               7
# ItemsInCart          10
# ShippingAddress     655
# Date                671
# CustomerID         1189
# UnitPrice          1193
# TotalPrice         1195
# OrderID            1200
# TrackingNumber     1200
# dtype: int64

# %%
referral_source = df['ReferralSource']
referral_source.value_counts().sort_values()
# Out:
# ReferralSource
# Referral     222
# Facebook     228
# Google       241
# Email        250
# Instagram    259
# Name: count, dtype: int64

# %%
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day
df.drop('Date', axis=1, inplace=True)
df
# Out:
#         OrderID CustomerID  Product  Quantity  UnitPrice ShippingAddress  \
# 0     ORD200000     C72649  Monitor         5     570.62     928 Main St
# 1     ORD200001     C75739    Phone         2     151.35     823 Main St
# 2     ORD200002     C81728   Tablet         5     550.68     512 Main St
# 3     ORD200003     C33540    Chair         1     273.19     275 Main St
# 4     ORD200004     C81840  Printer         4     626.01     668 Main St
# ...         ...        ...      ...       ...        ...             ...
# 1195  ORD201195     C21126     Desk         1     107.04     392 Main St
# 1196  ORD201196     C20095  Monitor         2     662.53     778 Main St
# 1197  ORD201197     C79674   Tablet         2     436.84     275 Main St
# 1198  ORD201198     C64753    Chair         4     262.52     509 Main St
# 1199  ORD201199     C57502   Tablet         4     560.58     201 Main St
#
#      PaymentMethod OrderStatus TrackingNumber  ItemsInCart CouponCode  \
# ...

# %%
print("Kurtosis:", df['UnitPrice'].kurt())
# Out:
# Kurtosis: -1.1910109277585115

# %%
print(f"Skewness: {df['UnitPrice'].skew()}")
# Out:
# Skewness: -0.026511641121850952

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df['UnitPrice'], bins=30, kde=True, color='purple')

plt.xlabel("Unit Price")
plt.ylabel("Frequency")
plt.title("Distribution of Unit Price")
plt.show()

# %%
df.columns
# Out:
# Index(['OrderID', 'CustomerID', 'Product', 'Quantity', 'UnitPrice',
#        'ShippingAddress', 'PaymentMethod', 'OrderStatus', 'TrackingNumber',
#        'ItemsInCart', 'CouponCode', 'ReferralSource', 'TotalPrice', 'Year',
#        'Month', 'Day'],
#       dtype='object')

# %%
total_price = df['TotalPrice']
total_price.plot(kind='hist', bins=20, color='red')
plt.show()

# %%
print(df['TotalPrice'].describe())
print("Skewness:", df['TotalPrice'].skew())
print("Kurtosis:", df['TotalPrice'].kurt())
# Out:
# count    1200.000000
# mean     1053.968300
# std       819.856558
# min        11.390000
# 25%       410.520000
# 50%       823.615000
# 75%      1578.475000
# max      3456.400000
# Name: TotalPrice, dtype: float64
# Skewness: 0.8913590826809059
# Kurtosis: -0.04041471740667113

# %%
df['TotalPrice'] = df['TotalPrice'].fillna(df['TotalPrice'].median())
# replaced with median because the column is right skewed so mean could be misleading while refering to central tendency

# %%
df = df[(df['TotalPrice'] != 0) & (df['TotalPrice'] > 0)]
df
# Out:
#         OrderID CustomerID  Product  Quantity  UnitPrice ShippingAddress  \
# 0     ORD200000     C72649  Monitor         5     570.62     928 Main St
# 1     ORD200001     C75739    Phone         2     151.35     823 Main St
# 2     ORD200002     C81728   Tablet         5     550.68     512 Main St
# 3     ORD200003     C33540    Chair         1     273.19     275 Main St
# 4     ORD200004     C81840  Printer         4     626.01     668 Main St
# ...         ...        ...      ...       ...        ...             ...
# 1195  ORD201195     C21126     Desk         1     107.04     392 Main St
# 1196  ORD201196     C20095  Monitor         2     662.53     778 Main St
# 1197  ORD201197     C79674   Tablet         2     436.84     275 Main St
# 1198  ORD201198     C64753    Chair         4     262.52     509 Main St
# 1199  ORD201199     C57502   Tablet         4     560.58     201 Main St
#
#      PaymentMethod OrderStatus TrackingNumber  ItemsInCart CouponCode  \
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(x=df['TotalPrice'])
plt.show()

# %%
Q1 = df['TotalPrice'].quantile(0.25)
Q3 = df['TotalPrice'].quantile(0.75)
IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = df[(df['TotalPrice'] < lower) | (df['TotalPrice'] > upper)]

print("Number of outliers:", len(outliers))
print("Percentage:", len(outliers) / len(df) * 100)
df = df[(df['TotalPrice'] >= lower) & (df['TotalPrice'] <= upper)]
# Out:
# Number of outliers: 8
# Percentage: 0.6666666666666667

# %%
df
# Out:
#         OrderID CustomerID  Product  Quantity  UnitPrice ShippingAddress  \
# 0     ORD200000     C72649  Monitor         5     570.62     928 Main St
# 1     ORD200001     C75739    Phone         2     151.35     823 Main St
# 2     ORD200002     C81728   Tablet         5     550.68     512 Main St
# 3     ORD200003     C33540    Chair         1     273.19     275 Main St
# 4     ORD200004     C81840  Printer         4     626.01     668 Main St
# ...         ...        ...      ...       ...        ...             ...
# 1195  ORD201195     C21126     Desk         1     107.04     392 Main St
# 1196  ORD201196     C20095  Monitor         2     662.53     778 Main St
# 1197  ORD201197     C79674   Tablet         2     436.84     275 Main St
# 1198  ORD201198     C64753    Chair         4     262.52     509 Main St
# 1199  ORD201199     C57502   Tablet         4     560.58     201 Main St
#
#      PaymentMethod OrderStatus TrackingNumber  ItemsInCart CouponCode  \
# ...

# %%
total_price = df['TotalPrice']
total_price.plot(kind='hist', bins=20, color='red')
plt.show()

# %%
print("Skewness:", df['TotalPrice'].skew()) #final check
print("Kurtosis:", df['TotalPrice'].kurt())
# Out:
# Skewness: 0.85894248867459
# Kurtosis: -0.13111447834500112

# %%
df['PricePerItem'] = df['TotalPrice'] / df['Quantity']
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5660\1803743039.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PricePerItem'] = df['TotalPrice'] / df['Quantity']

# %%
df['CartUtilization'] = df['Quantity'] / df['ItemsInCart']
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5660\3342650193.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['CartUtilization'] = df['Quantity'] / df['ItemsInCart']

# %%
df
# Out:
#         OrderID CustomerID  Product  Quantity  UnitPrice ShippingAddress  \
# 0     ORD200000     C72649  Monitor         5     570.62     928 Main St
# 1     ORD200001     C75739    Phone         2     151.35     823 Main St
# 2     ORD200002     C81728   Tablet         5     550.68     512 Main St
# 3     ORD200003     C33540    Chair         1     273.19     275 Main St
# 4     ORD200004     C81840  Printer         4     626.01     668 Main St
# ...         ...        ...      ...       ...        ...             ...
# 1195  ORD201195     C21126     Desk         1     107.04     392 Main St
# 1196  ORD201196     C20095  Monitor         2     662.53     778 Main St
# 1197  ORD201197     C79674   Tablet         2     436.84     275 Main St
# 1198  ORD201198     C64753    Chair         4     262.52     509 Main St
# 1199  ORD201199     C57502   Tablet         4     560.58     201 Main St
#
#      PaymentMethod OrderStatus TrackingNumber  ItemsInCart CouponCode  \
# ...

# %%
df['IsReferred'] = df['ReferralSource'].notna().astype(int)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5660\2406197125.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['IsReferred'] = df['ReferralSource'].notna().astype(int)

# %%
df
# Out:
#         OrderID CustomerID  Product  Quantity  UnitPrice ShippingAddress  \
# 0     ORD200000     C72649  Monitor         5     570.62     928 Main St
# 1     ORD200001     C75739    Phone         2     151.35     823 Main St
# 2     ORD200002     C81728   Tablet         5     550.68     512 Main St
# 3     ORD200003     C33540    Chair         1     273.19     275 Main St
# 4     ORD200004     C81840  Printer         4     626.01     668 Main St
# ...         ...        ...      ...       ...        ...             ...
# 1195  ORD201195     C21126     Desk         1     107.04     392 Main St
# 1196  ORD201196     C20095  Monitor         2     662.53     778 Main St
# 1197  ORD201197     C79674   Tablet         2     436.84     275 Main St
# 1198  ORD201198     C64753    Chair         4     262.52     509 Main St
# 1199  ORD201199     C57502   Tablet         4     560.58     201 Main St
#
#      PaymentMethod OrderStatus TrackingNumber  ItemsInCart CouponCode  \
# ...

# %%
df.to_csv("data/cleaned_data.csv", index=False)

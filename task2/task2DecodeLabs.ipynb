# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/creditcard.csv')

df.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5     2 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6     4  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7     7 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8     7 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9     9 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
df.isna().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    1
# Class     1
# dtype: int64

# %%
df
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 13949  24754  1.252924 -0.182189 -0.802716 -0.210981  1.916713  3.643624
# 13950  24756 -0.346979 -2.103284 -0.685061  1.961605 -0.401125  0.473632
# 13951  24759 -6.053652 -5.988723  0.810413 -0.011811  1.308135 -0.590803
# 13952  24759  1.169121 -1.284945  0.032717 -0.681670  0.660598  4.412578
# 13953  24759 -6.917152  5.854171 -1.652458 -1.488884 -0.833891 -0.344418
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 0          0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1          0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2          1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3          1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4          2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...      ...       ...       ...       ...       ...       ...       ...
# 13948  24753 -0.565780  0.754977  0.737825  0.030154 -1.383391  0.268107
# 13949  24754  1.252924 -0.182189 -0.802716 -0.210981  1.916713  3.643624
# 13950  24756 -0.346979 -2.103284 -0.685061  1.961605 -0.401125  0.473632
# 13951  24759 -6.053652 -5.988723  0.810413 -0.011811  1.308135 -0.590803
# 13952  24759  1.169121 -1.284945  0.032717 -0.681670  0.660598  4.412578
#
#              V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

time = df['Time']

plt.hist(time, bins= 10, color='red', density=True)
sns.kdeplot(time, color='blue')
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.title('Distribution of Time')
plt.show() # bimodial

# %%
print(time.skew())
print(time.kurtosis()) # very light tails. No outliers confirmed!
# Out:
# 0.3988943870700611
# -1.2073203780995083

# %%
print(time.mean()) # the mean lies between the two modes (bimodial) and does not represent the central tendency of either cluster particularly well.
print(time.median())
# Out:
# 10120.112735612413
# 9086.0

# %%
import scipy.stats as stats

stats.probplot(time, dist='norm', plot=plt)
plt.xlabel('Quantiles')
plt.ylabel('Time')
plt.title('Normal Probability Plot')
plt.show() # not normal. from edges!

# %%
plt.boxplot(time)
plt.xlabel('Time')
plt.ylabel('Frequency')
plt.title('Distribution of Time')
plt.show()

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
amount = df['Amount']
amount.sample(10)
# Out:
# 4387      20.15
# 3089      18.67
# 8085      39.00
# 4731       2.69
# 10413     10.21
# 7327       0.00
# 1758      77.26
# 1623       9.00
# 7810     132.84
# 5436       4.06
# Name: Amount, dtype: float64

# %%
plt.hist(amount, bins=20, color='red', density=True)
sns.kdeplot(amount, color='blue')
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.title('Distribution of Amount')
plt.show()

# %%
print(amount.skew()) # very right skewed hence, many outliers, let's check it with central tendency measure
print(amount.kurtosis()) #very heavy tails!
# Out:
# 12.777678672438562
# 340.68230621256953

# %%
print(amount.mean())
print(amount.median()) # median and mean are far apart, proved by skewness !
# Out:
# 63.88244176879524
# 15.69

# %%
plt.boxplot(amount)
plt.xlabel('Amount')
plt.ylabel('Frequency')
plt.title('Distribution of Amount')
plt.show()

# %%
cat = df['Class']
# fraud class is minority class. Can be solved using SMOTE (Synthetic Minority Oversampling Technique)
cat.value_counts()
# Out:
# Class
# 0.0    13897
# 1.0       56
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler

scalar = StandardScaler()
df['Time'] = scalar.fit_transform(df[['Time']])
df['Amount'] = scalar.fit_transform(df[['Amount']])

# %%
X = df.drop('Class', axis=1)
Y = df['Class']

# %%
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split

smote = SMOTE(sampling_strategy='minority', random_state=42, k_neighbors=1)
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

logistic = LogisticRegression(
    max_iter=1000,
    random_state=42
)
logistic.fit(X_train_resampled, y_train_resampled)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
rf = RandomForestClassifier(
    n_estimators=100,
    random_state=42,
    n_jobs=-1
)
rf.fit(X_train_resampled, y_train_resampled)
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

y_pred = logistic.predict(X_test)
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.9931924041562165
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.99      1.00      2780
#          1.0       0.36      0.91      0.51        11
#
#     accuracy                           0.99      2791
#    macro avg       0.68      0.95      0.75      2791
# weighted avg       1.00      0.99      0.99      2791

# %%
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap ='Reds')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
y_pred1 = rf.predict(X_test)
print(accuracy_score(y_test, y_pred1))
print(classification_report(y_test, y_pred1)) #Random Forest performed better for this fraud detection task!
# Out:
# 0.9992834109638122
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00      2780
#          1.0       0.91      0.91      0.91        11
#
#     accuracy                           1.00      2791
#    macro avg       0.95      0.95      0.95      2791
# weighted avg       1.00      1.00      1.00      2791

# %%
cm = confusion_matrix(y_test, y_pred1)
sns.heatmap(cm, annot=True, fmt='d', cmap ='Reds')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()
